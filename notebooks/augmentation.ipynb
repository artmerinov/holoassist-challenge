# %%
import os
os.chdir('../')

# %%
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from typing import List, Union, Tuple, Dict

import cv2
from IPython.display import clear_output
from time import sleep

import math
import random
from collections import defaultdict
from einops.layers.torch import Rearrange

import torch
from torchvision.transforms import Compose
from torch.utils.data import DataLoader

from src.opts.opts import parser
from src.utils.reproducibility import make_reproducible
from src.models.model import VideoModel
from src.dataset.video_dataset import VideoDataset
from src.dataset.video_transforms import (
    IdentityTransform,
    GroupScale, 
    GroupCenterCrop, 
    GroupRandomCrop,
    GroupMultiScaleCrop,
    Stack, 
    ToTorchFormatTensor, 
    GroupNormalize, 
    GroupRandomHorizontalFlip,
    GroupRotate
)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
args = parser.parse_args(args=[])
args.base_model = 'InceptionV3'
args.fusion_mode = "GSF"
args.__dict__
# Out:
# {'holoassist_dir': '/Users/artemmerinov/data/holoassist',
#  'raw_annotation_file': '/Users/artemmerinov/data/holoassist/data-annotation-trainval-v1_1.json',
#  'split_dir': '/Users/artemmerinov/data/holoassist/data-splits-v1',
#  'fine_grained_actions_map_file': '/Users/artemmerinov/data/holoassist/fine_grained_actions_map.txt',
#  'dataset_name': 'holoassist',
#  'fusion_mode': 'GSF',
#  'base_model': 'InceptionV3',
#  'num_segments': 8,
#  'dropout': 0.5,
#  'num_epochs': 10,
#  'batch_size': 16,
#  'lr': 0.01,
#  'momentum': 0.9,
#  'weight_decay': 0.0005,
#  'clip_gradient': None,
#  'checkpoint_interval': 3,
#  'runs_path': 'runs/',
#  'num_workers': 4}

# %%
if args.dataset_name == 'holoassist':
    num_classes = 1887 # actions
    tr_list_file = "/Users/artemmerinov/data/holoassist/data-splits-v1.train-v1.txt"
    va_list_file = "/Users/artemmerinov/data/holoassist/data-splits-v1.val-v1.txt"
else:
    raise NotImplementedError()

# %%
# Fix random state to make results reproducible
make_reproducible(random_seed=0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VideoModel(
    num_classes=num_classes, 
    num_segments=args.num_segments, 
    base_model=args.base_model,
    fusion_mode=args.fusion_mode,
    dropout=args.dropout,
    verbose=False,
).to(device)
# print(model)

input_size = model.input_size
crop_size = model.crop_size
scale_size = model.scale_size
input_mean = model.input_mean
input_std = model.input_std
learnable_named_parameters = model.learnable_named_parameters

tr_dataset = VideoDataset(
    raw_annotation_file=args.raw_annotation_file,
    split_dir=args.split_dir,
    holoassist_dir=args.holoassist_dir,
    fine_grained_actions_map_file=args.fine_grained_actions_map_file,
    num_segments=args.num_segments,
    transform=None,
    mode="train"
)
# Out:
# Making reproducible on seed 0
# => Using GSF fusion
# No. of GSF modules = 11
# There are 7 videos in the list There are 7 videos as video files There are 0 videos that present in the list but are missing as videos.
# Number of clips in dataset: 507

# %%
def animate(frames):

    plt.figure()
    for i in range(len(frames)):
        plt.imshow(frames[i])
        plt.axis('off')  
        plt.show()
        sleep(0.1)
        clear_output(wait=True)

# %%
frames, action = tr_dataset[0]
print(action)
# Out:
# 96

# %%
frames
# Out:
# [<PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>,
#  <PIL.Image.Image image mode=RGB size=896x504>]

# %%
print(np.array(frames[0]).shape) # numpy
print(frames[0].size) # PIL Image
# Out:
# (504, 896, 3)
# (896, 504)

# %% [markdown]
# # Original

# %%
animate(frames)

# %% [markdown]
# # GroupScale

# %%
transform = GroupScale(size=50)
animate(transform((frames)))

# %% [markdown]
# # GroupRandomHorizontalFlip

# %%
transform = Compose([
    GroupScale(size=400),
    GroupRandomHorizontalFlip(),
])
animate(transform((frames)))

# %% [markdown]
# # GroupCenterCrop

# %%
transform = Compose([
    GroupScale(size=400),
    GroupCenterCrop(size=crop_size),
])
animate(transform((frames)))

# %% [markdown]
# # GroupRandomCrop

# %%
transform = Compose([
    GroupScale(size=350),
    GroupRandomCrop(size=crop_size)
])
animate(transform((frames)))

# %% [markdown]
# # GroupRotate

# %%
transform = Compose([
    GroupScale(size=350),
    GroupRotate(angle_range=(-30.0, 30.0), probability=1)
])
animate(transform((frames)))

# %% [markdown]
# # GroupMultiScaleCrop

# %%
transform = Compose([
    # GroupScale(size=350),
    GroupMultiScaleCrop(input_size=crop_size, scales=[1., 0.875, 0.75, 0.66])
])
animate(transform((frames)))
