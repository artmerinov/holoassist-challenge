# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Learning curves
#
#     ../logs/train_GSF_InceptionV3_SS1_bs32_ns16.log

# %%
tr_acc1_list = [0.196, 0.264, 0.294, 0.312, 0.324, 0.379, 0.386, 0.392, 0.395, 0.4, 0.444, 0.453, 0.456, 0.493, 0.501, 0.527, 0.537, 0.542]
va_acc1_list = [0.231, 0.274, 0.265, 0.302, 0.297, 0.353, 0.351, 0.359, 0.362, 0.358, 0.394, 0.401, 0.402, 0.42, 0.414, 0.438, 0.426, 0.431]

# plt.figure(figsize=(10,6))
plt.plot(np.arange(len(tr_acc1_list)), tr_acc1_list, color="r", lw=2, marker='o', label="train");
plt.plot(np.arange(len(va_acc1_list)), va_acc1_list, color="green", lw=2, marker='o', label="validation");
plt.grid(False);
# plt.title("Acc@1 for train and validation datasets", weight='bold', size=12, loc='left', pad=10)
plt.ylabel("Acc@1")
plt.xlabel("Epoch")
plt.xticks(np.arange(len(tr_acc1_list)));
plt.axvline(x=15, ls='--', color='k', )
plt.legend();

# Customize the plot to keep only the horizontal line (bottom spine)
ax = plt.gca()
# Hide all spines except for the bottom (x-axis) spine
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# %%
tr_loss_list = [4.04, 3.33, 3.11, 2.98, 2.9 ,2.59,2.54,2.51,2.48,2.46,2.24,2.2 ,2.18,2.01,1.96,1.85,1.81,1.78]
va_loss_list = [3.65,3.33,3.36,3.11,3.13,2.79,2.82,2.81,2.79,2.76,2.82,2.57,2.56 ,2.56,2.48,2.47,2.41,2.44,2.43]

# plt.figure(figsize=(10,6))
plt.plot(np.arange(len(tr_loss_list)), tr_loss_list, color="r", lw=2, marker='o', label="train");
plt.plot(np.arange(len(va_loss_list)), va_loss_list, color="green", lw=2, marker='o', label="validation");
plt.grid(False);
# plt.title("Loss for train and validation datasets", weight='bold', size=12, loc='left', pad=10)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.xticks(np.arange(len(tr_loss_list)));
plt.axvline(x=15, ls='--', color='k', )
plt.legend();

# Customize the plot to keep only the horizontal line (bottom spine)
ax = plt.gca()
# Hide all spines except for the bottom (x-axis) spine
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# %% [markdown]
# # Repeats

# %%
rep_acc1_list = [0.432, 0.455, 0.463, 0.465, 0.470, 0.470, 0.471, 0.472, 0.475, 0.475]

plt.plot(np.arange(len(rep_acc1_list)), rep_acc1_list, color="purple", lw=2, marker='o');
plt.grid(False);
plt.xlabel("Repetition number")
plt.ylabel("Acc@1")
# plt.ylim(0.4, 0.8)
plt.xticks(np.arange(len(rep_acc1_list)));

# Customize the plot to keep only the horizontal line (bottom spine)
ax = plt.gca()
# Hide all spines except for the bottom (x-axis) spine
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# %%
rep_acc5_list = [0.731, 0.751, 0.756, 0.761, 0.765, 0.765, 0.764, 0.765, 0.766, 0.766]

plt.plot(np.arange(len(rep_acc5_list)), rep_acc5_list, color="purple", lw=2, marker='o');
plt.grid(False);
plt.xlabel("Repetition number")
plt.ylabel("Acc@5")
# plt.ylim(0.4, 0.8)
plt.xticks(np.arange(len(rep_acc5_list)));

# Customize the plot to keep only the horizontal line (bottom spine)
ax = plt.gca()
# Hide all spines except for the bottom (x-axis) spine
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# %% [markdown]
# # Fusion modules comparison

# %%
GSF_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/acc/GSF_InceptionV3_SS1_bs32_ns16_2024-06-07_14-35-15.csv")
GSM_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/acc/GSM_InceptionV3_SS1_bs32_ns16_2024-06-09_09-18-41.csv")
TSM_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/acc/TSM_InceptionV3_SS1_bs32_ns16_2024-06-07_11-27-28.csv")
TSN_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/acc/TSN_InceptionV3_SS1_bs32_ns16_2024-06-10_21-05-19.csv")
GSF_InceptionV3_ImageNet_bs32_ns16 = pd.read_csv("learning_curves/acc/GSF_InceptionV3_ImageNet_bs32_ns16_2024-06-08_23-04-58.csv")
GSF_InceptionV3_ImageNet_bs32_ns8 = pd.read_csv("learning_curves/acc/GSF_InceptionV3_ImageNet_bs32_ns8_2024-06-10_11-21-19.csv")
GSF_ResNet50_ImageNet_bs32_ns8 = pd.read_csv("learning_curves/acc/GSF_ResNet50_ImageNet_bs32_ns8_2024-06-10_14-58-18.csv")

plt.figure(figsize=(8,6))

plt.plot(GSF_InceptionV3_SS1_bs32_ns16["Step"].values, 
         GSF_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="GSF_InceptionV3_SS1_bs32_ns16",
         color="limegreen", lw=2, marker='o');

plt.plot(GSM_InceptionV3_SS1_bs32_ns16["Step"].values, 
         GSM_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="GSM_InceptionV3_SS1_bs32_ns16",
         color="grey", lw=2, marker='o');

# plt.plot(GSF_InceptionV3_ImageNet_bs32_ns16["Step"].values, 
#          GSF_InceptionV3_ImageNet_bs32_ns16["Value"].values, 
#          label="GSF_InceptionV3_ImageNet_bs32_ns16",
#          color="lightblue", lw=2, marker='o');

plt.plot(TSM_InceptionV3_SS1_bs32_ns16["Step"].values, 
         TSM_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="TSM_InceptionV3_SS1_bs32_ns16",
         color="violet", lw=2, marker='o');

plt.plot(TSN_InceptionV3_SS1_bs32_ns16["Step"].values, 
         TSN_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="TSN_InceptionV3_SS1_bs32_ns16",
         color="orange", lw=2, marker='o');


# plt.title("Comparison of Learning Curves w.r.t. the Fusion Method", weight='bold', size=12, loc='left', pad=10)
plt.xlabel("Epoch")
plt.ylabel("Acc@1")
plt.axvline(x=15, color='k', lw=1.5, linestyle='--')
plt.legend();

# Customize the plot to keep only the horizontal line (bottom spine)
ax = plt.gca()
# Hide all spines except for the bottom (x-axis) spine
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# %%
GSF_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/loss/GSF_InceptionV3_SS1_bs32_ns16_2024-06-07_14-35-15.csv")
GSM_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/loss/GSM_InceptionV3_SS1_bs32_ns16_2024-06-09_09-18-41.csv")
TSN_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/loss/TSN_InceptionV3_SS1_bs32_ns16_2024-06-10_21-05-19.csv")
TSM_InceptionV3_SS1_bs32_ns16 = pd.read_csv("learning_curves/loss/TSM_InceptionV3_SS1_bs32_ns16_2024-06-07_11-27-28.csv")


plt.figure(figsize=(8,6))

plt.plot(GSF_InceptionV3_SS1_bs32_ns16["Step"].values, 
         GSF_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="GSF_InceptionV3_SS1_bs32_ns16",
         color="limegreen", lw=2, marker='o');

plt.plot(GSM_InceptionV3_SS1_bs32_ns16["Step"].values, 
         GSM_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="GSM_InceptionV3_SS1_bs32_ns16",
         color="grey", lw=2, marker='o');

# plt.plot(GSF_InceptionV3_ImageNet_bs32_ns16["Step"].values, 
#          GSF_InceptionV3_ImageNet_bs32_ns16["Value"].values, 
#          label="GSF_InceptionV3_ImageNet_bs32_ns16",
#          color="lightblue", lw=2, marker='o');

plt.plot(TSM_InceptionV3_SS1_bs32_ns16["Step"].values, 
         TSM_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="TSM_InceptionV3_SS1_bs32_ns16",
         color="violet", lw=2, marker='o');

plt.plot(TSN_InceptionV3_SS1_bs32_ns16["Step"].values, 
         TSN_InceptionV3_SS1_bs32_ns16["Value"].values, 
         label="TSN_InceptionV3_SS1_bs32_ns16",
         color="orange", lw=2, marker='o');


# plt.title("Comparison of Learning Curves w.r.t. the Fusion Method", weight='bold', size=12, loc='left', pad=10)
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.axvline(x=15, color='k', lw=1.5, linestyle='--')
plt.legend(loc="upper right");

# Customize the plot to keep only the horizontal line (bottom spine)
ax = plt.gca()
# Hide all spines except for the bottom (x-axis) spine
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
